# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# aiobotocore                              2.7.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.12.15
# aioitertools                             0.7.1
# aiosignal                                1.4.0
# alabaster                                0.7.12
# altair                                   5.0.1
# anaconda-anon-usage                      0.4.3
# anaconda-catalogs                        0.2.0
# anaconda-client                          1.12.3
# anaconda-cloud-auth                      0.1.4
# anaconda-navigator                       2.5.2
# anaconda-project                         0.11.1
# aniso8601                                10.0.1
# annotated-types                          0.7.0
# anyio                                    4.9.0
# appdirs                                  1.4.4
# ...

# %%
import pandas

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# this is testing of jupyter notebook
